# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs

# %%
x, y_true = make_blobs(
    n_samples=100,
    centers=3,
    cluster_std=0.9,
)
x.shape
# Out:
# (100, 2)

# %%
print(x[:5])
# Out:
# [[-7.97406084 -5.99761458]
#  [-5.61197307  7.70685813]
#  [-8.09062188 -7.42678769]
#  [-5.4976636   7.10914177]
#  [-6.68165979 -6.800788  ]]

# %%
plt.plot(x.T[0], x.T[1], 'gx')

# %% [markdown]
# ## k-means

# %%
from sklearn.cluster import KMeans

# %%
kmeans = KMeans(n_clusters=3)
kmeans.fit(x)
center = kmeans.cluster_centers_
# Out:
# c:\Users\Admin\miniconda3\envs\aiml\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
print(center)
# Out:
# [[ 2.54196335  0.27271037]
#  [-7.77219189 -6.2419554 ]
#  [-5.25039394  7.36047378]]

# %%
plt.plot(x.T[0], x.T[1], 'gx')
plt.plot(center.T[0], center.T[1], 'rv')

# %% [markdown]
# __Silhouette coef__

# %%
from sklearn.metrics import silhouette_score, davies_bouldin_score

# %%
sil_score = []
davies_score = []
elbow_score = []

for i in range(2,11):
    cluster = KMeans(n_clusters=i)
    cluster.fit(x)
    centroids = cluster.labels_
    sil_score += [silhouette_score(x, centroids, metric="euclidean")]   
    davies_score += [davies_bouldin_score(x, centroids)]   
    elbow_score += [cluster.inertia_]
# Out:
# c:\Users\Admin\miniconda3\envs\aiml\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\Admin\miniconda3\envs\aiml\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\Admin\miniconda3\envs\aiml\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\Admin\miniconda3\envs\aiml\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\Admin\miniconda3\envs\aiml\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\Admin\miniconda3\envs\aiml\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\Admin\miniconda3\envs\aiml\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\Admin\miniconda3\envs\aiml\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\Admin\miniconda3\envs\aiml\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
plt.plot(range(2,11),sil_score)
plt.xlabel("value of K")
plt.ylabel("silhouette_score")
plt.title("silhouette analysis")
# Out:
# Text(0.5, 1.0, 'silhouette analysis')

# %%
plt.plot(range(2,11),davies_score)
plt.xlabel("value of K")
plt.ylabel("davies_bouldin")
plt.title("davies_bouldin analysis")
# Out:
# Text(0.5, 1.0, 'davies_bouldin analysis')

# %%
plt.plot(range(2,11),elbow_score)
plt.xlabel("value of K")
plt.ylabel("")
plt.title("elbow analysis")
# Out:
# Text(0.5, 1.0, 'elbow analysis')
